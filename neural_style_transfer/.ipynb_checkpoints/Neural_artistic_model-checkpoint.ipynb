# %% [markdown]
# ## Implementing neural style transfer model
#
# This technique is outlined in the paper - <i>A Neural Algorithm of Artistic Style</i>. Based on the paper, I require a conv net which is trained on a large volume of images and has subsequently learned how to accurately classify images of different classes. I decided to use the VGG-19 model as described in the paper. I am using a [pretrained model](http://www.vlfeat.org/matconvnet/pretrained/#downloading-the-pre-trained-models) and am using a variation of a helper function found on [Github](https://github.com/JudasDie) to quickly read in the model.
#
# Note - "Loading parameters" in this case is essentially taking the generated image from earlier training and inputting that as the generated image for continued learning.

# %%
import scipy.io
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import latex
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
np.random.seed(10)

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Global variables for image height,width
n_h = 1200
n_w = 900

# %%
# Initial images with valid shapes used for testing and first run through model

# Creating a randomly generated image
gen_img = np.random.rand(n_w,n_h,3)
# Loading content and style images
content_img = cv2.imread("../../data/neural_style/content_1.jpg") # christmas tree with presents
content_img = cv2.resize(content_img, (n_h,n_w), interpolation=cv2.INTER_AREA)
style_img = cv2.imread("../../data/neural_style/style_1.jpg") # bright painting
style_img = cv2.resize(style_img, (n_h,n_w), interpolation=cv2.INTER_AREA)

# %%
# Adjusting shapes
gen_img.shape = (1,n_w,n_h,3)
content_img.shape = (1,n_w,n_h,3)
style_img.shape = (1,n_w,n_h,3)

# %%
# Loads the VGG model based on pretrained parameters
def load_vgg_model(path,img_height,img_width,num_channels):
    vgg = scipy.io.loadmat(path)
    vgg_layers = vgg['layers']
    
    def _weights(layer, expected_layer_name): # Return weights and bias from VGG model for layer
        wb = vgg_layers[0][layer][0][0][2]
        W = wb[0][0]
        b = wb[0][1]
        layer_name = vgg_layers[0][layer][0][0][0][0]
        assert layer_name == expected_layer_name
        return W, b

    def _relu(conv2d_layer): # Return relu function
        return tf.nn.relu(conv2d_layer)

    def _conv2d(prev_layer, layer, layer_name): # Return Conv2d layer using trained weights
        W, b = _weights(layer, layer_name)
        W = tf.constant(W)
        b = tf.constant(np.reshape(b, (b.size)))
        return tf.nn.conv2d(prev_layer, filter=W, strides=[1, 1, 1, 1], padding='SAME') + b

    def _conv2d_relu(prev_layer, layer, layer_name): # Returns Conv+Relu using pretrained weights
        return _relu(_conv2d(prev_layer, layer, layer_name))

    def _avgpool(prev_layer): # Returns AVGPool layer
        return tf.nn.avg_pool(prev_layer, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

    # Constructs the graph
    graph = {}
    graph['input']   = tf.Variable(np.zeros((1, img_height,img_width,num_channels)), dtype = 'float32')
    graph['conv1_1']  = _conv2d_relu(graph['input'], 0, 'conv1_1')
    graph['conv1_2']  = _conv2d_relu(graph['conv1_1'], 2, 'conv1_2')
    graph['avgpool1'] = _avgpool(graph['conv1_2'])
    graph['conv2_1']  = _conv2d_relu(graph['avgpool1'], 5, 'conv2_1')
    graph['conv2_2']  = _conv2d_relu(graph['conv2_1'], 7, 'conv2_2')
    graph['avgpool2'] = _avgpool(graph['conv2_2'])
    graph['conv3_1']  = _conv2d_relu(graph['avgpool2'], 10, 'conv3_1')
    graph['conv3_2']  = _conv2d_relu(graph['conv3_1'], 12, 'conv3_2')
    graph['conv3_3']  = _conv2d_relu(graph['conv3_2'], 14, 'conv3_3')
    graph['conv3_4']  = _conv2d_relu(graph['conv3_3'], 16, 'conv3_4')
    graph['avgpool3'] = _avgpool(graph['conv3_4'])
    graph['conv4_1']  = _conv2d_relu(graph['avgpool3'], 19, 'conv4_1')
    graph['conv4_2']  = _conv2d_relu(graph['conv4_1'], 21, 'conv4_2')
    graph['conv4_3']  = _conv2d_relu(graph['conv4_2'], 23, 'conv4_3')
    graph['conv4_4']  = _conv2d_relu(graph['conv4_3'], 25, 'conv4_4')
    graph['avgpool4'] = _avgpool(graph['conv4_4'])
    graph['conv5_1']  = _conv2d_relu(graph['avgpool4'], 28, 'conv5_1')
    graph['conv5_2']  = _conv2d_relu(graph['conv5_1'], 30, 'conv5_2')
    graph['conv5_3']  = _conv2d_relu(graph['conv5_2'], 32, 'conv5_3')
    graph['conv5_4']  = _conv2d_relu(graph['conv5_3'], 34, 'conv5_4')
    graph['avgpool5'] = _avgpool(graph['conv5_4'])
    
    return graph

# %%
# Getting the output shapes for each layer of the model
tf.reset_default_graph()
with tf.Session() as sess:
    model = load_vgg_model("../../vgg/imagenet-vgg-verydeep-19.mat",n_w,n_h,3)
    sess.run(model["input"].assign(gen_img))
    cv11 = sess.run(model["conv1_1"])
    _,cv11w,cv11h,cv11c = cv11.shape
    print("conv1_1:",cv11.shape)
    cv21 = sess.run(model["conv2_1"])
    _,cv21w,cv21h,cv21c = cv21.shape
    print("conv2_1:",cv21.shape)
    cv31 = sess.run(model["conv3_1"])
    _,cv31w,cv31h,cv31c = cv31.shape
    print("conv3_1:",cv31.shape)
    cv41 = sess.run(model["conv4_1"])
    _,cv41w,cv41h,cv41c = cv41.shape
    print("conv4_1:",cv41.shape)
    cv51 = sess.run(model["conv5_1"])
    _,cv51w,cv51h,cv51c = cv51.shape
    print("conv5_1:",cv51.shape)
    cv42 = sess.run(model["conv4_2"])
    print("conv4_2:",cv42.shape)
    _,cv42w,cv42h,cv42c = cv42.shape
# Out:
# conv1_1: (1, 900, 1200, 64)
# conv2_1: (1, 450, 600, 128)
# conv3_1: (1, 225, 300, 256)
# conv4_1: (1, 113, 150, 512)
# conv5_1: (1, 57, 75, 512)
# conv4_2: (1, 113, 150, 512)

# %% [markdown]
# ## Building content and style cost functions
#
# ### Style cost function
#
# $$ J_{content}(C,G) = \frac{1}{2} || a^{[l](C)} - a^{[l](G)} ||^2$$
#
# ### Content cost function
#
# $$ E_l(S,G) = \frac{1}{4 (n_h n_w)^2 n_c^2} || g^{[l](S)} - g^{[l](G)} ||^2 $$
#
# $$ J_{style} = \sum_{l=0}^{L} w_l * E_l $$
#
# ### Total cost
#
# $$  J_{total} = \alpha * J_{content} + \beta * J_{style} $$
#
# $$ \frac{\alpha}{\beta} = 1*10^{-3} $$
#
#
# Terms:
# - C: content image
# - S: style image
# - G: generated image
# - g: gram-matrix between two channels of a given activation
# - a<sup>(l)(x)</sup>: activation for layer l of image x
# - w<sub>l</sub>: weighting factors for each layers contribution to the style loss
#
# As described in the paper mentioned above, I will be matching the content representation on layer "conv4_2". I will be matching the style representation on the layers "conv1_1", "conv2_1", "conv3_1", "conv4_1", "conv5_1" with each receiving an equal weighting.

# %% [markdown]
# #### Content cost function

# %%
# Content cost function
def content_cost(cont_act,gen_act):
    """
    cont_act: content image activation for layer "conv4_2", shape (1,38,50,512)
    gen_act: generated image activation for layer "conv4_2"
    """
    m,n_w,n_h,n_c = gen_act.get_shape().as_list()
    cont_act_u = tf.reshape(cont_act,(n_w*n_h,n_c)) # shape:(1,n_h*n_w,n_c)
    gen_act_u = tf.reshape(gen_act,(n_w*n_h,n_c))
    content_diff = tf.square(tf.subtract(cont_act_u,gen_act_u))
    content_cost = (1/(8*n_w)) * tf.reduce_sum(content_diff)
    return content_cost

# %%
# Testing content cost function
tf.reset_default_graph()
with tf.Session() as sess:
    model = load_vgg_model("../../vgg/imagenet-vgg-verydeep-19.mat",n_w,n_h,3)
    # Computation graph
    Content = tf.placeholder(tf.float32,(None,cv42w,cv42h,cv42c))
    Gen = tf.placeholder(tf.float32,(None,cv42w,cv42h,cv42c))
    J_content = content_cost(Content, Gen)
    # Getting input data
    sess.run(model["input"].assign(content_img)) # getting content image
    aContent = sess.run(model["conv4_2"])
    sess.run(model["input"].assign(gen_img))
    aGen = sess.run(model["conv4_2"])
    # Running graph
    cost_content = sess.run(J_content,feed_dict={Content:aContent,Gen:aGen})
    print("Content cost:",cost_content)
# Out:
# Content cost: 837145800.0

# %% [markdown]
# #### Style cost function

# %%
# Returns the gram matrix for a specific matrix of shape (n_c,n_h*n_w)
def gram_matrix(act):
    act_t = tf.transpose(act)
    return tf.matmul(act,act_t) # shape:(n_c,n_c)

# %%
# Computes style loss for a single layer, takes in two tf placeholders
def single_layer_style_cost(style_act,gen_act):
    m,n_w,n_h,n_c = gen_act.get_shape().as_list()
    style_act_t = tf.transpose(tf.reshape(style_act, (n_h*n_w, n_c))) # shape: (1,n_c,n_w*n_h)
    gen_act_t = tf.transpose(tf.reshape(gen_act, (n_h*n_w, n_c))) # shape: (1,n_c,n_w*n_h)
    gram_style = gram_matrix(style_act_t)
    gram_gen = gram_matrix(gen_act_t)
    style_diff = tf.square(tf.subtract(gram_style,gram_gen))
    style_cost = (1/(4 * (n_h*n_w)**2 * n_c**2)) * tf.reduce_sum(style_diff)
    return style_cost

# %%
# Testing style cost function
tf.reset_default_graph()
with tf.Session() as sess:
    model = load_vgg_model("../../vgg/imagenet-vgg-verydeep-19.mat",n_w,n_h,3)
    # Computation graph
    Style = tf.placeholder(tf.float32,(None,cv21w,cv21h,cv21c))
    Gen = tf.placeholder(tf.float32,(None,cv21w,cv21h,cv21c))
    J_style = single_layer_style_cost(Style, Gen)
    # Getting input data
    sess.run(model["input"].assign(style_img)) # getting content image
    aStyle = sess.run(model["conv2_1"])
    sess.run(model["input"].assign(gen_img))
    aGen = sess.run(model["conv2_1"])
    # Running graph
    cost_style = sess.run(J_style,feed_dict={Style:aStyle,Gen:aGen})
    print("Style cost:",cost_style)
# Out:
# Style cost: 92317760.0

# %%
# The style cost weights each layers activations equally
# Takes a list of layers as strings (i.e. "conv2_1") corresponding to layers used for style loss
def style_cost(layers,model,sess):
    total_cost = 0
    for layer in layers:
        activation = model[layer]
        style_act = sess.run(activation)
        gen_act = activation # evaluated when we assign the generated image to the model
        layer_cost = single_layer_style_cost(style_act,gen_act)
        total_cost += (0.2 * layer_cost)
        
    return total_cost

# %% [markdown]
# #### Total cost function

# %%
# Full cost function
def cost_function(style_cost,content_cost,alpha=1,beta=2):
    return alpha * content_cost + beta * style_cost

# %% [markdown]
# ### Tensorflow Model

# %%
# shape: specifies the shape of the images (width,height)
def style_model(gen_img,cont_img,style_img,shape,model,lr=2,epochs=180,print_cost=True):
    tf.reset_default_graph() # reset graph
    costs = []
    g_images = []
    layers = ["conv1_1","conv2_1","conv3_1","conv4_1","conv5_1"] # layers to be used for style cost
    n_w,n_h = shape
    sess = tf.InteractiveSession() # Using an interactive session
    model = load_vgg_model("../../vgg/imagenet-vgg-verydeep-19.mat",n_w,n_h,3) # loading conv-net
    
    # Computation graph: 
    sess.run(model['input'].assign(cont_img)) # content cost
    act = model['conv4_2']
    cont_act = sess.run(act)
    gen_cont_act = act
    j_content = content_cost(cont_act,gen_cont_act)
    sess.run(model['input'].assign(style_img)) # style cost
    j_style = style_cost(layers,model,sess)
    cost = cost_function(j_style,j_content) # total cost
    
    optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(cost)
    init = tf.global_variables_initializer() # initialize variables
    sess.run(init)
    sess.run(model['input'].assign(gen_img)) # Assigning the generated image to the model
    
    for epoch in range(epochs):
        _,a_cost = sess.run([optimizer,cost])
        costs.append(a_cost)
        generated_img = sess.run(model['input']) # Getting generated image
        g_images.append(generated_img)
        
        if print_cost and epoch % 1 == 0: # print cost every iter
            print("cost at epoch {}: {}".format(epoch+1,a_cost))
            
        if print_cost and epoch % 10 == 0: # print style,content cost
            j_con,j_sty = sess.run([j_content,j_style])
            print("Content cost at epoch {}: {}".format(epoch+1,j_con))
            print("Style cost at epoch {}: {}".format(epoch+1,j_sty))
            print("---------------------------")
            
    return g_images,costs

# %%
# Changing shapes for visualization
gen_img.shape = (n_w,n_h,3)
content_img.shape = (n_w,n_h,3)
style_img.shape = (n_w,n_h,3)

# %%
# Visualizing input images
plt.imshow(gen_img)
plt.show()
print("randomly generated image")
# Out:
# randomly generated image

# %%
# Visualizing input images
plt.imshow(cv2.cvtColor(content_img, cv2.COLOR_BGR2RGB)) # cv2 reads in images in reverse channel order
plt.show()
print("Content image")
# Out:
# Content image

# %%
# Visualizing input images
plt.imshow(cv2.cvtColor(style_img, cv2.COLOR_BGR2RGB))
plt.show()
print("Style image")
# Out:
# Style image

# %%
# Changing shapes for model input
gen_img.shape = (1,n_w,n_h,3)
content_img.shape = (1,n_w,n_h,3)
style_img.shape = (1,n_w,n_h,3)

# %% [markdown]
# ### Generating Image
#
# Note - matplotlib is displaying these images incorrectly, they should be darker. I didn't look to alter this output though, as I thought it was visually interesting in itself.

# %%
ag_images,acosts = style_model(gen_img,content_img,style_img,[n_w,n_h],model,lr=2,epochs=200,print_cost=True)
# Out:
# cost at epoch 1: 1483706752.0
# Content cost at epoch 1: 823503360.0
# Style cost at epoch 1: 322071968.0
# ---------------------------
# cost at epoch 2: 1467647232.0
# cost at epoch 3: 1430228352.0
# cost at epoch 4: 1386768640.0
# cost at epoch 5: 1339664640.0
# cost at epoch 6: 1290194944.0
# cost at epoch 7: 1239355904.0
# cost at epoch 8: 1188256768.0
# cost at epoch 9: 1137994112.0
# cost at epoch 10: 1089533312.0
# cost at epoch 11: 1043561728.0
# Content cost at epoch 11: 559869440.0
# Style cost at epoch 11: 220306288.0
# ---------------------------
# cost at epoch 12: 1000482048.0
# cost at epoch 13: 960449280.0
# cost at epoch 14: 923484800.0
# cost at epoch 15: 889506752.0
# cost at epoch 16: 858365952.0
# cost at epoch 17: 829826816.0
# cost at epoch 18: 803628928.0
# cost at epoch 19: 779498368.0
# cost at epoch 20: 757186432.0
# cost at epoch 21: 736497856.0
# Content cost at epoch 21: 418476384.0
# Style cost at epoch 21: 149388448.0
# ---------------------------
# cost at epoch 22: 717253248.0
# cost at epoch 23: 699317248.0
# cost at epoch 24: 682522496.0
# cost at epoch 25: 666745216.0
# cost at epoch 26: 651886336.0
# cost at epoch 27: 637836800.0
# cost at epoch 28: 624520576.0
# cost at epoch 29: 611888320.0
# cost at epoch 30: 599882560.0
# cost at epoch 31: 588461312.0
# Content cost at epoch 31: 328111200.0
# Style cost at epoch 31: 124736440.0
# ---------------------------
# cost at epoch 32: 577584064.0
# cost at epoch 33: 567212800.0
# cost at epoch 34: 557300800.0
# cost at epoch 35: 547812160.0
# cost at epoch 36: 538732800.0
# cost at epoch 37: 530038784.0
# cost at epoch 38: 521703424.0
# cost at epoch 39: 513694496.0
# cost at epoch 40: 505987968.0
# cost at epoch 41: 498573440.0
# Content cost at epoch 41: 271688320.0
# Style cost at epoch 41: 109876512.0
# ---------------------------
# cost at epoch 42: 491441344.0
# cost at epoch 43: 484568256.0
# cost at epoch 44: 477935808.0
# cost at epoch 45: 471531808.0
# cost at epoch 46: 465350880.0
# cost at epoch 47: 459384096.0
# cost at epoch 48: 453612896.0
# cost at epoch 49: 448021888.0
# cost at epoch 50: 442606656.0
# cost at epoch 51: 437358720.0
# Content cost at epoch 51: 234919008.0
# Style cost at epoch 51: 98675952.0
# ---------------------------
# cost at epoch 52: 432270912.0
# cost at epoch 53: 427329216.0
# cost at epoch 54: 422520608.0
# cost at epoch 55: 417845568.0
# cost at epoch 56: 413298528.0
# cost at epoch 57: 408877536.0
# cost at epoch 58: 404581184.0
# cost at epoch 59: 400404480.0
# cost at epoch 60: 396339392.0
# cost at epoch 61: 392387136.0
# Content cost at epoch 61: 208974864.0
# Style cost at epoch 61: 89783584.0
# ---------------------------
# cost at epoch 62: 388542016.0
# cost at epoch 63: 384796256.0
# cost at epoch 64: 381145088.0
# cost at epoch 65: 377585920.0
# cost at epoch 66: 374116736.0
# cost at epoch 67: 370735104.0
# cost at epoch 68: 367436160.0
# cost at epoch 69: 364220352.0
# cost at epoch 70: 361083136.0
# cost at epoch 71: 358020288.0
# Content cost at epoch 71: 189734512.0
# Style cost at epoch 71: 82648784.0
# ---------------------------
# cost at epoch 72: 355032064.0
# cost at epoch 73: 352115456.0
# cost at epoch 74: 349268864.0
# cost at epoch 75: 346490368.0
# cost at epoch 76: 343777472.0
# cost at epoch 77: 341129600.0
# cost at epoch 78: 338542336.0
# cost at epoch 79: 336015168.0
# cost at epoch 80: 333548544.0
# cost at epoch 81: 331140800.0
# Content cost at epoch 81: 174929184.0
# Style cost at epoch 81: 76929232.0
# ---------------------------
# cost at epoch 82: 328787648.0
# cost at epoch 83: 326486336.0
# cost at epoch 84: 324234656.0
# cost at epoch 85: 322033632.0
# cost at epoch 86: 319884352.0
# cost at epoch 87: 317784512.0
# cost at epoch 88: 315731328.0
# cost at epoch 89: 313720896.0
# cost at epoch 90: 311755680.0
# cost at epoch 91: 309832800.0
# Content cost at epoch 91: 163212688.0
# Style cost at epoch 91: 72369592.0
# ---------------------------
# cost at epoch 92: 307951872.0
# cost at epoch 93: 306110208.0
# cost at epoch 94: 304306912.0
# cost at epoch 95: 302542144.0
# cost at epoch 96: 300814400.0
# cost at epoch 97: 299122240.0
# cost at epoch 98: 297464128.0
# cost at epoch 99: 295840192.0
# cost at epoch 100: 294248928.0
# cost at epoch 101: 292688992.0
# Content cost at epoch 101: 153779376.0
# Style cost at epoch 101: 68690576.0
# ---------------------------
# cost at epoch 102: 291160512.0
# cost at epoch 103: 289661696.0
# cost at epoch 104: 288193408.0
# cost at epoch 105: 286754240.0
# cost at epoch 106: 285344320.0
# cost at epoch 107: 283962112.0
# cost at epoch 108: 282608192.0
# cost at epoch 109: 281280640.0
# cost at epoch 110: 279977152.0
# cost at epoch 111: 278698912.0
# Content cost at epoch 111: 146014176.0
# Style cost at epoch 111: 65715708.0
# ---------------------------
# cost at epoch 112: 277445600.0
# cost at epoch 113: 276216320.0
# cost at epoch 114: 275009120.0
# cost at epoch 115: 273824608.0
# cost at epoch 116: 272660160.0
# cost at epoch 117: 271516896.0
# cost at epoch 118: 270394848.0
# cost at epoch 119: 269292992.0
# cost at epoch 120: 268211328.0
# cost at epoch 121: 267148240.0
# Content cost at epoch 121: 139474384.0
# Style cost at epoch 121: 63314720.0
# ---------------------------
# cost at epoch 122: 266103824.0
# cost at epoch 123: 265078672.0
# cost at epoch 124: 264072032.0
# cost at epoch 125: 263083808.0
# cost at epoch 126: 262112656.0
# cost at epoch 127: 261158656.0
# cost at epoch 128: 260220512.0
# cost at epoch 129: 259296864.0
# cost at epoch 130: 258387376.0
# cost at epoch 131: 257492960.0
# Content cost at epoch 131: 134032264.0
# Style cost at epoch 131: 61289928.0
# ---------------------------
# cost at epoch 132: 256612128.0
# cost at epoch 133: 255746224.0
# cost at epoch 134: 254894880.0
# cost at epoch 135: 254056864.0
# cost at epoch 136: 253232880.0
# cost at epoch 137: 252422688.0
# cost at epoch 138: 251625744.0
# cost at epoch 139: 250841664.0
# cost at epoch 140: 250069856.0
# cost at epoch 141: 249310080.0
# Content cost at epoch 141: 129409760.0
# Style cost at epoch 141: 59576672.0
# ---------------------------
# cost at epoch 142: 248563104.0
# cost at epoch 143: 247827600.0
# cost at epoch 144: 247103808.0
# cost at epoch 145: 246390416.0
# cost at epoch 146: 245687456.0
# cost at epoch 147: 244995984.0
# cost at epoch 148: 244314768.0
# cost at epoch 149: 243642784.0
# cost at epoch 150: 242980576.0
# cost at epoch 151: 242327936.0
# Content cost at epoch 151: 125449984.0
# Style cost at epoch 151: 58117348.0
# ---------------------------
# cost at epoch 152: 241684672.0
# cost at epoch 153: 241050272.0
# cost at epoch 154: 240425408.0
# cost at epoch 155: 239808992.0
# cost at epoch 156: 239200832.0
# cost at epoch 157: 238601248.0
# cost at epoch 158: 238009184.0
# cost at epoch 159: 237424576.0
# cost at epoch 160: 236847616.0
# cost at epoch 161: 236278784.0
# Content cost at epoch 161: 122085504.0
# Style cost at epoch 161: 56815980.0
# ---------------------------
# cost at epoch 162: 235717472.0
# cost at epoch 163: 235162976.0
# cost at epoch 164: 234615488.0
# cost at epoch 165: 234075328.0
# cost at epoch 166: 233541696.0
# cost at epoch 167: 233015568.0
# cost at epoch 168: 232495328.0
# cost at epoch 169: 231980672.0
# cost at epoch 170: 231472576.0
# cost at epoch 171: 230970848.0
# Content cost at epoch 171: 119110408.0
# Style cost at epoch 171: 55682568.0
# ---------------------------
# cost at epoch 172: 230475552.0
# cost at epoch 173: 229986688.0
# cost at epoch 174: 229503872.0
# cost at epoch 175: 229026848.0
# cost at epoch 176: 228555664.0
# cost at epoch 177: 228089696.0
# cost at epoch 178: 227629360.0
# cost at epoch 179: 227174176.0
# cost at epoch 180: 226725376.0
# cost at epoch 181: 226281632.0
# Content cost at epoch 181: 116532144.0
# Style cost at epoch 181: 54655124.0
# ---------------------------
# cost at epoch 182: 225842400.0
# cost at epoch 183: 225408480.0
# cost at epoch 185: 224555552.0
# cost at epoch 186: 224136864.0
# cost at epoch 187: 223722080.0
# cost at epoch 188: 223311920.0
# cost at epoch 189: 222906112.0
# cost at epoch 190: 222504928.0
# cost at epoch 191: 222108144.0
# Content cost at epoch 191: 114240848.0
# Style cost at epoch 191: 53737080.0
# ---------------------------
# cost at epoch 192: 221715008.0
# cost at epoch 193: 221327264.0
# cost at epoch 194: 220942544.0
# cost at epoch 195: 220561664.0
# cost at epoch 196: 220184192.0
# cost at epoch 197: 219811168.0
# cost at epoch 198: 219442240.0
# cost at epoch 199: 219078016.0
# cost at epoch 200: 218716656.0

# %%
imgtest1 = ag_images[-1]
imgtest1.shape = (n_w,n_h,3)
plt.imshow(imgtest1)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imgtest1_input = imgtest1
imgtest1_input.shape = (1,n_w,n_h,3)

# %%
ag_images2,acosts2 = style_model(imgtest1_input,content_img,style_img,[n_w,n_h],model,lr=1.5,epochs=200,print_cost=True)
# Out:
# cost at epoch 1: 218357920.0
# Content cost at epoch 1: 115162864.0
# Style cost at epoch 1: 52564120.0
# ---------------------------
# cost at epoch 2: 220291104.0
# cost at epoch 3: 219084816.0
# cost at epoch 4: 217119584.0
# cost at epoch 5: 215999104.0
# cost at epoch 6: 214962368.0
# cost at epoch 7: 213899840.0
# cost at epoch 8: 212982144.0
# cost at epoch 9: 212099504.0
# cost at epoch 10: 211221152.0
# cost at epoch 11: 210383168.0
# Content cost at epoch 11: 107511752.0
# Style cost at epoch 11: 51036380.0
# ---------------------------
# cost at epoch 12: 209584512.0
# cost at epoch 13: 208798800.0
# cost at epoch 14: 208025856.0
# cost at epoch 15: 207273792.0
# cost at epoch 16: 206543168.0
# cost at epoch 17: 205829616.0
# cost at epoch 18: 205133696.0
# cost at epoch 19: 204451488.0
# cost at epoch 20: 203781856.0
# cost at epoch 21: 203126272.0
# Content cost at epoch 21: 103355240.0
# Style cost at epoch 21: 49564836.0
# ---------------------------
# cost at epoch 22: 202484912.0
# cost at epoch 23: 201856016.0
# cost at epoch 24: 201239488.0
# cost at epoch 25: 200634016.0
# cost at epoch 26: 200038896.0
# cost at epoch 27: 199455520.0
# cost at epoch 28: 198883056.0
# cost at epoch 29: 198320736.0
# cost at epoch 30: 197767408.0
# cost at epoch 31: 197223904.0
# Content cost at epoch 31: 100277096.0
# Style cost at epoch 31: 48206692.0
# ---------------------------
# cost at epoch 32: 196690480.0
# cost at epoch 33: 196165856.0
# cost at epoch 34: 195649792.0
# cost at epoch 35: 195143312.0
# cost at epoch 36: 194645280.0
# cost at epoch 37: 194154528.0
# cost at epoch 38: 193671904.0
# cost at epoch 39: 193197888.0
# cost at epoch 40: 192731712.0
# cost at epoch 41: 192273632.0
# Content cost at epoch 41: 97811112.0
# Style cost at epoch 41: 47005752.0
# ---------------------------
# cost at epoch 42: 191822624.0
# cost at epoch 43: 191377824.0
# cost at epoch 44: 190940336.0
# cost at epoch 45: 190509792.0
# cost at epoch 46: 190085920.0
# cost at epoch 47: 189668928.0
# cost at epoch 48: 189258000.0
# cost at epoch 49: 188854096.0
# cost at epoch 50: 188456464.0
# cost at epoch 51: 188065472.0
# Content cost at epoch 51: 95743280.0
# Style cost at epoch 51: 45967800.0
# ---------------------------
# cost at epoch 52: 187678880.0
# cost at epoch 53: 187298608.0
# cost at epoch 54: 186923680.0
# cost at epoch 55: 186555952.0
# cost at epoch 56: 186192432.0
# cost at epoch 57: 185836272.0
# cost at epoch 58: 185482592.0
# cost at epoch 59: 185135008.0
# cost at epoch 60: 184791232.0
# cost at epoch 61: 184452288.0
# Content cost at epoch 61: 94046912.0
# Style cost at epoch 61: 45035960.0
# ---------------------------
# cost at epoch 62: 184118832.0
# cost at epoch 63: 183788320.0
# cost at epoch 64: 183463168.0
# cost at epoch 65: 183142400.0
# cost at epoch 66: 182825584.0
# cost at epoch 67: 182514080.0
# cost at epoch 68: 182206464.0
# cost at epoch 69: 181904832.0
# cost at epoch 70: 181607296.0
# cost at epoch 71: 181311552.0
# Content cost at epoch 71: 92610416.0
# Style cost at epoch 71: 44206136.0
# ---------------------------
# cost at epoch 72: 181022688.0
# cost at epoch 73: 180735776.0
# cost at epoch 74: 180455120.0
# cost at epoch 75: 180175616.0
# cost at epoch 76: 179900816.0
# cost at epoch 77: 179630096.0
# cost at epoch 78: 179361744.0
# cost at epoch 79: 179098112.0
# cost at epoch 80: 178840960.0
# cost at epoch 81: 178584768.0
# Content cost at epoch 81: 91422456.0
# Style cost at epoch 81: 43455648.0
# ---------------------------
# cost at epoch 82: 178333760.0
# cost at epoch 83: 178086976.0
# cost at epoch 84: 177847024.0
# cost at epoch 85: 177602304.0
# cost at epoch 86: 177362352.0
# cost at epoch 87: 177130448.0
# cost at epoch 88: 176898160.0
# cost at epoch 89: 176671456.0
# cost at epoch 90: 176447008.0
# cost at epoch 91: 176227264.0
# Content cost at epoch 91: 90408712.0
# Style cost at epoch 91: 42799268.0
# ---------------------------
# cost at epoch 92: 176007248.0
# cost at epoch 93: 175793440.0
# cost at epoch 94: 175580816.0
# cost at epoch 95: 175366432.0
# cost at epoch 96: 175160672.0
# cost at epoch 97: 174955008.0
# cost at epoch 98: 174750096.0
# cost at epoch 99: 174551968.0
# cost at epoch 100: 174354144.0
# cost at epoch 101: 174160704.0
# Content cost at epoch 101: 89555360.0
# Style cost at epoch 101: 42207660.0
# ---------------------------
# cost at epoch 102: 173970688.0
# cost at epoch 103: 173783232.0
# cost at epoch 104: 173593792.0
# cost at epoch 105: 173416624.0
# cost at epoch 106: 173229248.0
# cost at epoch 107: 173049024.0
# cost at epoch 108: 172863504.0
# cost at epoch 109: 172691664.0
# cost at epoch 110: 172515456.0
# cost at epoch 111: 172338720.0
# Content cost at epoch 111: 88824312.0
# Style cost at epoch 111: 41676932.0
# ---------------------------
# cost at epoch 112: 172178176.0
# cost at epoch 113: 172007008.0
# cost at epoch 114: 171850784.0
# cost at epoch 115: 171679280.0
# cost at epoch 116: 171517728.0
# cost at epoch 117: 171356672.0
# cost at epoch 118: 171196736.0
# cost at epoch 119: 171032960.0
# cost at epoch 120: 170881024.0
# cost at epoch 121: 170732560.0
# Content cost at epoch 121: 88149792.0
# Style cost at epoch 121: 41219884.0
# ---------------------------
# cost at epoch 122: 170589568.0
# cost at epoch 123: 170448640.0
# cost at epoch 124: 170312704.0
# cost at epoch 125: 170174592.0
# cost at epoch 126: 170037600.0
# cost at epoch 127: 169884928.0
# cost at epoch 128: 169721552.0
# cost at epoch 129: 169574208.0
# cost at epoch 130: 169433040.0
# cost at epoch 131: 169299776.0
# Content cost at epoch 131: 87628200.0
# Style cost at epoch 131: 40771108.0
# ---------------------------
# cost at epoch 132: 169170416.0
# cost at epoch 133: 169033472.0
# cost at epoch 134: 168903184.0
# cost at epoch 135: 168768000.0
# cost at epoch 136: 168636192.0
# cost at epoch 137: 168503648.0
# cost at epoch 138: 168376608.0
# cost at epoch 139: 168250384.0
# cost at epoch 140: 168128800.0
# cost at epoch 141: 168006304.0
# Content cost at epoch 141: 87098560.0
# Style cost at epoch 141: 40396192.0
# ---------------------------
# cost at epoch 142: 167890944.0
# cost at epoch 143: 167768992.0
# cost at epoch 144: 167656704.0
# cost at epoch 145: 167545120.0
# cost at epoch 146: 167427712.0
# cost at epoch 147: 167325888.0
# cost at epoch 148: 167217792.0
# cost at epoch 149: 167116256.0
# cost at epoch 150: 166999200.0
# cost at epoch 151: 166900832.0
# Content cost at epoch 151: 86783496.0
# Style cost at epoch 151: 40003964.0
# ---------------------------
# cost at epoch 152: 166791424.0
# cost at epoch 153: 166686880.0
# cost at epoch 154: 166580032.0
# cost at epoch 155: 166474368.0
# cost at epoch 156: 166370240.0
# cost at epoch 157: 166275952.0
# cost at epoch 158: 166178784.0
# cost at epoch 159: 166094176.0
# cost at epoch 160: 166010432.0
# cost at epoch 161: 165908576.0
# Content cost at epoch 161: 86103960.0
# Style cost at epoch 161: 39856396.0
# ---------------------------
# cost at epoch 162: 165816752.0
# cost at epoch 163: 165704544.0
# cost at epoch 164: 165594528.0
# cost at epoch 165: 165490048.0
# cost at epoch 166: 165392784.0
# cost at epoch 167: 165300320.0
# cost at epoch 168: 165213616.0
# cost at epoch 169: 165129408.0
# cost at epoch 170: 165035264.0
# cost at epoch 171: 164946880.0
# Content cost at epoch 171: 86067144.0
# Style cost at epoch 171: 39396312.0
# ---------------------------
# cost at epoch 172: 164859776.0
# cost at epoch 173: 164772864.0
# cost at epoch 174: 164683360.0
# cost at epoch 175: 164602528.0
# cost at epoch 176: 164523744.0
# cost at epoch 177: 164442784.0
# cost at epoch 178: 164375120.0
# cost at epoch 179: 164303312.0
# cost at epoch 180: 164245984.0
# cost at epoch 181: 164197728.0
# Content cost at epoch 181: 85904648.0
# Style cost at epoch 181: 39120556.0
# ---------------------------
# cost at epoch 182: 164145760.0
# cost at epoch 183: 164068464.0
# cost at epoch 184: 163969296.0
# cost at epoch 185: 163860960.0
# cost at epoch 186: 163780080.0
# cost at epoch 187: 163729264.0
# cost at epoch 188: 163660800.0
# cost at epoch 189: 163594624.0
# cost at epoch 190: 163500704.0
# cost at epoch 191: 163431040.0
# Content cost at epoch 191: 85574640.0
# Style cost at epoch 191: 38884528.0
# ---------------------------
# cost at epoch 192: 163343696.0
# cost at epoch 193: 163283088.0
# cost at epoch 194: 163210352.0
# cost at epoch 195: 163140640.0
# cost at epoch 196: 163068192.0
# cost at epoch 197: 162995632.0
# cost at epoch 198: 162934080.0
# cost at epoch 199: 162861664.0
# cost at epoch 200: 162810016.0

# %%
imgtest2 = ag_images2[-1]
imgtest2.shape = (n_w,n_h,3)
plt.imshow(imgtest2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imgtest3 = ag_images2[100]
imgtest3.shape = (n_w,n_h,3)
plt.imshow(imgtest3)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Reversing colors
plt.imshow(cv2.cvtColor(imgtest3, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Saving all frames

# %%
all_imgs = ag_images + ag_images2
print(len(all_imgs))
# Out:
# 400

# %%
for img in all_imgs:
    img.shape = (n_w,n_h,3)

# %%
img_array = np.array(all_imgs)
img_array.shape = (400,n_w,n_h,3)
print(img_array.shape)
# Out:
# (400, 900, 1200, 3)

# %%
np.save("./img_array_tree.npy",img_array)

# %%
i = 0
for img in img_array:
    cv2.imwrite('./images/tree'+str(i)+".png",img)
    i += 1
